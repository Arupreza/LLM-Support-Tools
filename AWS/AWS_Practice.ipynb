# %% [markdown]
# ## Create Key-Pair for Secure Connection

# %%
import boto3

# %%
ec2 = boto3.client('ec2')

ec2.describe_instances()

response  = ec2.create_key_pair(KeyName = 'TestLinux')

# %%
response
# Out:
# {'KeyPairId': 'key-0f332f381a26f7b14',
#  'KeyName': 'TestLinux',
#  'KeyFingerprint': '39:72:bc:c9:b7:ff:2e:72:e7:57:5d:55:9a:d3:cf:95:96:eb:52:4c',
# ...

# %%
file = open("Cred/TestLinux.pem", "w")
file.write(response['KeyMaterial'])
file.close()

# %% [markdown]
# ## Create an Amazon EC2 instance

# %%
ec2 = boto3.client('ec2')
ec2.describe_instances()

response = ec2.run_instances(
    ImageId='ami-0bdd88bd06d16ba03',  # Example: Ubuntu 22.04 in ap-southeast-2
    InstanceType='t3.small',
    MinCount=1,
    MaxCount=1,
    KeyName='TestLinux',              # Replace with your actual key pair name
    BlockDeviceMappings = [
        {
            "DeviceName" : "/dev/xvda",
            "Ebs" : {
                "DeleteOnTermination" : True,
                "VolumeSize" : 20               
            }
        }
    ]
)

# %%
ec2.describe_instances()
# Out:
# {'Reservations': [{'ReservationId': 'r-0cf41a77c9c2bdd9f',
#    'OwnerId': '418541840270',
#    'Groups': [],
#    'Instances': [{'Architecture': 'x86_64',
#      'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#        'Ebs': {'AttachTime': datetime.datetime(2025, 11, 1, 13, 49, 35, tzinfo=tzutc()),
#         'DeleteOnTermination': True,
#         'Status': 'attached',
#         'VolumeId': 'vol-09345b66047810e8d'}}],
#      'ClientToken': '9dc8b489-4507-4219-890f-095dd3f78de3',
#      'EbsOptimized': False,
#      'EnaSupport': True,
#      'Hypervisor': 'xen',
#      'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#         'PublicDnsName': 'ec2-54-242-144-167.compute-1.amazonaws.com',
#         'PublicIp': '54.242.144.167'},
#        'Attachment': {'AttachTime': datetime.datetime(2025, 11, 1, 13, 49, 35, tzinfo=tzutc()),
#         'AttachmentId': 'eni-attach-0f8cc61e591f02efe',
#         'DeleteOnTermination': True,
#         'DeviceIndex': 0,
# ...

# %% [markdown]
# ## Create Security Group and add rules to it
# - Security groups control inbound and outbound traffic of the EC2 instance network interface.
# - every EC2 instance must have at least one Security Group associated with it. If no Security Group has been specified during the EC2 instance launch, the default Security Group of the default VPC is associated with the instance.

# %%
response = ec2.describe_security_groups()
response
# Out:
# {'SecurityGroups': [{'GroupId': 'sg-0d0d6cb5292f50415',
#    'IpPermissionsEgress': [{'IpProtocol': '-1',
#      'UserIdGroupPairs': [],
#      'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#      'Ipv6Ranges': [],
#      'PrefixListIds': []}],
#    'VpcId': 'vpc-0c03a49eeb1e9f9af',
#    'SecurityGroupArn': 'arn:aws:ec2:us-east-1:418541840270:security-group/sg-0d0d6cb5292f50415',
#    'OwnerId': '418541840270',
#    'GroupName': 'default',
#    'Description': 'default VPC security group',
#    'IpPermissions': [{'IpProtocol': '-1',
#      'UserIdGroupPairs': [{'UserId': '418541840270',
#        'GroupId': 'sg-0d0d6cb5292f50415'}],
#      'IpRanges': [],
#      'Ipv6Ranges': [],
#      'PrefixListIds': []}]}],
#  'ResponseMetadata': {'RequestId': '5de10640-56fa-4bd3-b2f6-9a8d4fbf6c82',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '5de10640-56fa-4bd3-b2f6-9a8d4fbf6c82',
#    'cache-control': 'no-cache, no-store',
# ...

# %%
response = ec2.create_security_group(
    GroupName = "TestLinux",
    Description = "Security group for testing..."
    
)

# %%
response
# Out:
# {'GroupId': 'sg-0e89e5edc12fbed03',
#  'SecurityGroupArn': 'arn:aws:ec2:us-east-1:418541840270:security-group/sg-0e89e5edc12fbed03',
#  'ResponseMetadata': {'RequestId': '36e6faa5-4f0d-49c6-98c3-8396c963485c',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '36e6faa5-4f0d-49c6-98c3-8396c963485c',
#    'cache-control': 'no-cache, no-store',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'content-type': 'text/xml;charset=UTF-8',
#    'content-length': '373',
#    'date': 'Sat, 01 Nov 2025 14:21:57 GMT',
#    'server': 'AmazonEC2'},
#   'RetryAttempts': 0}}

# %%
security_group_id = 'sg-0e89e5edc12fbed03' #response['Group']

# %%
response = ec2.authorize_security_group_ingress(
    GroupId=security_group_id,   # ✅ Correct key: GroupId (not GroupID)
    IpPermissions=[
        {
            "IpProtocol": "tcp",       # ✅ Added missing comma
            "FromPort": 22,
            "ToPort": 22,
            "IpRanges": [
                {"CidrIp": "0.0.0.0/0"}
            ]
        }
    ]
)

# %%
response
# Out:
# {'Return': True,
#  'SecurityGroupRules': [{'SecurityGroupRuleId': 'sgr-0126f8d13f7adfad6',
#    'GroupId': 'sg-0e89e5edc12fbed03',
#    'GroupOwnerId': '418541840270',
#    'IsEgress': False,
#    'IpProtocol': 'tcp',
#    'FromPort': 22,
#    'ToPort': 22,
#    'CidrIpv4': '0.0.0.0/0',
#    'SecurityGroupRuleArn': 'arn:aws:ec2:us-east-1:418541840270:security-group-rule/sgr-0126f8d13f7adfad6'}],
#  'ResponseMetadata': {'RequestId': '9b316e37-10be-4890-a162-d63a051f45c7',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '9b316e37-10be-4890-a162-d63a051f45c7',
#    'cache-control': 'no-cache, no-store',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'content-type': 'text/xml;charset=UTF-8',
#    'content-length': '696',
#    'date': 'Sat, 01 Nov 2025 14:32:21 GMT',
#    'server': 'AmazonEC2'},
#   'RetryAttempts': 0}}

# %%
res = ec2.describe_instances()
Instance_Id = res['Reservations'][0]['Instances'][0]['InstanceId']
OldGroupId = res['Reservations'][0]['Instances'][0]['SecurityGroups'][0]['GroupId']

# %%
response = ec2.modify_instance_attribute(
    InstanceId=Instance_Id,
    Groups=[OldGroupId, security_group_id] 
)

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': '9c144dd5-029f-4a03-8d49-6d060c13e500',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '9c144dd5-029f-4a03-8d49-6d060c13e500',
#    'cache-control': 'no-cache, no-store',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'content-type': 'text/xml;charset=UTF-8',
#    'content-length': '235',
#    'date': 'Sat, 01 Nov 2025 14:50:47 GMT',
#    'server': 'AmazonEC2'},
#   'RetryAttempts': 0}}

# %%
## to disable the connecetion
# response = ec2.modify_instance_attribute(
#     InstanceId=Instance_Id,
#     Groups=[OldGroupId, OldGroupId] 
# )

# %% [markdown]
# ## Start, Stop and Delete Amazon EC2 instances

# %%
# status -> running, stopped, terminated, pending etc.

import time

def wait_for_status(instance_id, target_status):
    while True:
        response = ec2.describe_instances(InstanceIds=instance_id)

        status = response['Reservations'][0]['Instances'][0]['State']['Name']

        if status == target_status:
            print("Instance is in {} state".format(target_status))
            break
        
        time.sleep(10)


def start_instances(instance_id):
    print("EC2 Instance Start")
    ec2.start_instances(InstanceIds=instance_id)

    wait_for_status(instance_id, 'running')





def stop_instances(instance_id):
    print("EC2 Instance Stop")
    ec2.stop_instances(InstanceIds=instance_id)

    wait_for_status(instance_id, 'stopped')



def terminate_instances(instance_id):
    print("EC2 Instance Termination")
    ec2.terminate_instances(InstanceIds=instance_id)

    wait_for_status(instance_id, 'terminated')

# %%
start_instances([Instance_Id])
# Out:
# EC2 Instance Start
# Instance is in running state

# %%
stop_instances([Instance_Id])
# Out:
# EC2 Instance Stop
# Instance is in stopped state

# %%
terminate_instances([Instance_Id])

# %% [markdown]
# ## S3 Tutorial

# %%
import boto3
s3 = boto3.client('s3')

# %%
response = s3.list_buckets()

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': 'XYYEDJMTGPRS8CYM',
#   'HostId': 'QS+xs2Odg1bhr2QL8kvVVrVAyzKfGeXaijEKSwfz4yGgB9DzhUP9lmEf1QMaPfjPzlGIyW1xCuU=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'QS+xs2Odg1bhr2QL8kvVVrVAyzKfGeXaijEKSwfz4yGgB9DzhUP9lmEf1QMaPfjPzlGIyW1xCuU=',
#    'x-amz-request-id': 'XYYEDJMTGPRS8CYM',
#    'date': 'Wed, 07 Jan 2026 08:20:58 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [],
#  'Owner': {'ID': '3987e15b0e9a862889b61cd64dd54904ff8c8d31ad604e1c5931ece9e9a8c3cf'}}

# %%
def create_bucket(bucket_name):
    s3 = boto3.client('s3')
    response = s3.create_bucket(
        Bucket=bucket_name,
        CreateBucketConfiguration={
            'LocationConstraint': 'ap-southeast-2'
        }
    )
    return response

# %%
create_bucket('arupreza-test-bucket-12345')
# Out:
# {'ResponseMetadata': {'RequestId': 'FSBAKQHNT8VQ4SNQ',
#   'HostId': 'foCwEkPHtMLdwoW58eWelHsEl2yrEheRDAvjijx9ocDrHTG5KI4XM5zGW8ze0zt7Vl6Fk0V8qEBLh9mekqZdnqhqmUh+MNSR',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'foCwEkPHtMLdwoW58eWelHsEl2yrEheRDAvjijx9ocDrHTG5KI4XM5zGW8ze0zt7Vl6Fk0V8qEBLh9mekqZdnqhqmUh+MNSR',
#    'x-amz-request-id': 'FSBAKQHNT8VQ4SNQ',
#    'date': 'Wed, 07 Jan 2026 08:21:04 GMT',
#    'location': 'http://arupreza-test-bucket-12345.s3.amazonaws.com/',
#    'x-amz-bucket-arn': 'arn:aws:s3:::arupreza-test-bucket-12345',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Location': 'http://arupreza-test-bucket-12345.s3.amazonaws.com/',
#  'BucketArn': 'arn:aws:s3:::arupreza-test-bucket-12345'}

# %% [markdown]
# ## Upload and rename the files

# %%
import os

# %%
bucket_name = 'arupreza-test-bucket-12345'
def upload_file(file_path, object_name = None):
    if object_name is None:
        object_name = os.path.basename(file_path)
    s3.upload_file(file_path, bucket_name, object_name)

# %%
upload_file("RLHF_data_for_sentiment_product_review.json")

# %%
upload_file("RLHF_data_for_sentiment_product_review.json", "Product_Sentoment.json")

# %% [markdown]
# ## List Objects

# %%
def list_objects():
    response = s3.list_objects_v2(Bucket=bucket_name)
    for obj in response.get('Contents', []):
        print(obj['Key'])

# %%
list_objects()
# Out:
# Product_Sentoment.json
# RLHF_data_for_sentiment_product_review.json

# %% [markdown]
# ## Download Files

# %%
def download_file(object_name, file_path):
    if not os.path.exists(os.path.dirname(file_path)):
        os.makedirs(os.path.dirname(file_path))
    s3.download_file(bucket_name, object_name, file_path)

# %%
download_file("Product_Sentoment.json", "Downloaded/Product_Sentoment.json")

# %% [markdown]
# ## Upload Directory

# %%
def upload_dir(dir_path, bucket_name, s3_prefix):
    for root, dirs, files in os.walk(dir_path):
        for file in files:
            local_path = os.path.join(root, file)
            rel_path = os.path.relpath(local_path, dir_path)
            s3_key = os.path.join(s3_prefix, rel_path).replace("\\", "/")
            
            # Corrected line: added bucket_name
            s3.upload_file(local_path, bucket_name, s3_key)
            print(f"Uploaded {local_path} to {s3_key}")

# %%
upload_dir("./Downloaded", "arupreza-test-bucket-12345", "backups/project_v1")
# Out:
# Uploaded ./Downloaded/Product_Sentoment.json to backups/project_v1/Product_Sentoment.json

# %% [markdown]
# ## Download Directory

# %%
def download_dir(bucket_name, s3_prefix, local_path):
    s3 = boto3.client('s3')
    paginator = s3.get_paginator("list_objects_v2")

    for result in paginator.paginate(Bucket=bucket_name, Prefix=s3_prefix):
        if 'Contents' in result:
            for item in result['Contents']:
                s3_key = item['Key']
                
                # 1. Define the local file path
                # relpath removes the s3_prefix from the local filename
                rel_path = os.path.relpath(s3_key, s3_prefix)
                local_file = os.path.join(local_path, rel_path)
                
                # 2. Create local subdirectories if they exist in S3 key
                local_file_dir = os.path.dirname(local_file)
                os.makedirs(local_file_dir, exist_ok=True)
                
                # 3. Download if the key is not a "folder" placeholder
                if not s3_key.endswith('/'):
                    s3.download_file(bucket_name, s3_key, local_file)
                    print(f"Downloaded: {s3_key} -> {local_file}")

# %%
bucket_name = "arupreza-test-bucket-12345"
local_path = "S3_Files"
s3_prefix = "backups/project_v1/"

# %%
download_dir(bucket_name, s3_prefix, local_path)
# Out:
# Downloaded: backups/project_v1/Product_Sentoment.json -> S3_Files/Product_Sentoment.json

# %% [markdown]
# ## Delete All The Files

# %%
def delete_s3_files(bucket_name, s3_prefix):
    s3 = boto3.client('s3')
    paginator = s3.get_paginator("list_objects_v2")

    for result in paginator.paginate(Bucket=bucket_name, Prefix=s3_prefix):
        if 'Contents' in result:
            for item in result['Contents']:
                s3_key = item['Key']
                s3.delete_object(Bucket=bucket_name, Key=s3_key)
                print(f"Deleted: {s3_key}")

# %%
delete_s3_files(bucket_name, s3_prefix)
# Out:
# Deleted: backups/project_v1/Product_Sentoment.json

# %%
def empty_s3_bucket(bucket_name):
    s3 = boto3.resource('s3')
    bucket = s3.Bucket(bucket_name)
    
    # This method handles pagination and batching automatically
    try:
        print(f"Starting deletion for bucket: {bucket_name}")
        
        # Deletes all objects and versions (if versioning is on)
        bucket.object_versions.delete()
        
        print(f"Bucket {bucket_name} is now empty.")
    except Exception as e:
        print(f"Error: {e}")

# %%
empty_s3_bucket(bucket_name)
# Out:
# Starting deletion for bucket: arupreza-test-bucket-12345
# Bucket arupreza-test-bucket-12345 is now empty.

# %%
from botocore.exceptions import ClientError

def delete_entire_s3_bucket(bucket_name):
    s3 = boto3.resource('s3')
    bucket = s3.Bucket(bucket_name)
    
    try:
        # 1. You must empty all versions and objects first
        print(f"Emptying bucket: {bucket_name}...")
        bucket.object_versions.delete()
        
        # 2. Delete the bucket itself
        print(f"Deleting bucket structure: {bucket_name}...")
        bucket.delete()
        
        print(f"Successfully removed bucket '{bucket_name}' from AWS.")
        
    except ClientError as e:
        print(f"AWS Error: {e.response['Error']['Message']}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
delete_entire_s3_bucket(bucket_name)
# Out:
# Emptying bucket: arupreza-test-bucket-12345...
# Deleting bucket structure: arupreza-test-bucket-12345...
# Successfully removed bucket 'arupreza-test-bucket-12345' from AWS.

# %% [markdown]
# ## Upload Models on AWS

# %%
import boto3
import os
import sys
from botocore.exceptions import ClientError

# -----------------------------------------------------------
# Global configuration values used across the script
# -----------------------------------------------------------
BUCKET_NAME = 'UIDSModels'
REGION = 'ap-southeast-2'

# -----------------------------------------------------------
# Create reusable boto3 interfaces
# -----------------------------------------------------------
s3_client = boto3.client('s3')
s3_resource = boto3.resource('s3')

def list_of_buckets():
    try:
        response = s3_client.list_buckets()
        buckets = [bucket['Name'] for bucket in response.get('Buckets', [])]
        print("Existing buckets:", buckets)
        return buckets
    except ClientError as e:
        print(f"Error listing buckets: {e}")
        return []

# %%
def create_bucket(bucket_name, region='ap-southeast-2'):
    s3_client = boto3.client('s3', region_name=region)
    bucket_name = bucket_name.lower()
    
    try:
        # Define config only if NOT in us-east-1
        config = {'LocationConstraint': region} if region != 'us-east-1' else None
        
        if config:
            s3_client.create_bucket(Bucket=bucket_name, CreateBucketConfiguration=config)
        else:
            s3_client.create_bucket(Bucket=bucket_name)
            
        print(f"Bucket '{bucket_name}' created successfully.")
        
    except ClientError as e:
        error_code = e.response['Error']['Code']
        if error_code == 'BucketAlreadyOwnedByYou':
            print(f"Cleanup: You already own '{bucket_name}'. Proceeding...")
        elif error_code == 'BucketAlreadyExists':
            print(f"Error: Name '{bucket_name}' is globally taken by someone else.")
        else:
            print(f"Critical Permission/Network Error: {e}")

# %%
list_of_buckets()
# Out:
# Existing buckets: ['arupreza-uids-models']
# ['arupreza-uids-models']

# %%
create_bucket('Arupreza-uids-models', 'ap-southeast-2')
# Out:
# Bucket 'arupreza-uids-models' created successfully.

# %%
def upload_dir(dir_path, bucket_name=BUCKET_NAME, s3_prefix=""):

    # Recursively uploads all files from a directory.
    try:
        for root, dirs, files in os.walk(dir_path):
            for file in files:

                local_path = os.path.join(root, file)
                rel_path = os.path.relpath(local_path, dir_path)

                s3_key = os.path.join(s3_prefix, rel_path).replace("\\", "/")

                s3_client.upload_file(local_path, bucket_name, s3_key)
                print(f"Uploaded: {local_path} -> {s3_key}")

    except Exception as e:
        print("Directory upload failed:", e)

# %%
traget_dir = "/home/lisa/Arupreza/UIDS/UIDS-II/SFTSrc/bert/TrainTesla/mobilebert-can-attack-classifier-experimental"

# %%
# Pass your valid bucket name as the second argument
upload_dir(traget_dir, bucket_name="arupreza-uids-models", s3_prefix="ONNXModels")
# Out:
# Uploaded: /home/lisa/Arupreza/UIDS/UIDS-II/SFTSrc/bert/TrainTesla/mobilebert-can-attack-classifier-experimental/vocab.txt -> ONNXModels/vocab.txt
# Uploaded: /home/lisa/Arupreza/UIDS/UIDS-II/SFTSrc/bert/TrainTesla/mobilebert-can-attack-classifier-experimental/training_args.bin -> ONNXModels/training_args.bin
# Uploaded: /home/lisa/Arupreza/UIDS/UIDS-II/SFTSrc/bert/TrainTesla/mobilebert-can-attack-classifier-experimental/special_tokens_map.json -> ONNXModels/special_tokens_map.json
# Uploaded: /home/lisa/Arupreza/UIDS/UIDS-II/SFTSrc/bert/TrainTesla/mobilebert-can-attack-classifier-experimental/model.safetensors -> ONNXModels/model.safetensors
# Uploaded: /home/lisa/Arupreza/UIDS/UIDS-II/SFTSrc/bert/TrainTesla/mobilebert-can-attack-classifier-experimental/tokenizer.json -> ONNXModels/tokenizer.json
# Uploaded: /home/lisa/Arupreza/UIDS/UIDS-II/SFTSrc/bert/TrainTesla/mobilebert-can-attack-classifier-experimental/config.json -> ONNXModels/config.json
# ...

# %%
def empty_s3_bucket(bucket_name):

    # Empties entire bucket including versions.
    try:
        print(f"Emptying bucket '{bucket_name}'...")

        bucket = s3_resource.Bucket(bucket_name)
        bucket.object_versions.delete()

        print(f"Bucket '{bucket_name}' is now empty.")

    except Exception as e:
        print("Empty bucket failed:", e)

# %%
empty_s3_bucket('arupreza-uids-models')
# Out:
# Emptying bucket 'arupreza-uids-models'...
# Bucket 'arupreza-uids-models' is now empty.

# %%
import boto3
from botocore.exceptions import ClientError

def delete_s3_directory(bucket_name, directory_prefix):
    # 1. Initialize inside the function to ensure fresh session
    s3_res = boto3.resource('s3')
    
    # 2. Strict prefix handling
    if not directory_prefix.endswith('/'):
        directory_prefix += '/'
    
    try:
        bucket = s3_res.Bucket(bucket_name)
        
        # 3. Use a collection to track what is being removed
        # Filter all versions (essential if versioning was ever on)
        versions = bucket.object_versions.filter(Prefix=directory_prefix)
        
        count = 0
        for version in versions:
            version.delete()
            count += 1
            
        if count == 0:
            print(f"No objects found with prefix '{directory_prefix}'. Check your path spelling.")
        else:
            print(f"Successfully deleted {count} object versions from '{directory_prefix}'.")
            
    except ClientError as e:
        print(f"AWS Error: {e.response['Error']['Message']}")
    except Exception as e:
        print(f"Error: {e}")

# %%
# IMPORTANT: Check your exact bucket name and prefix
delete_s3_directory('arupreza-uids-models', 'ONNXModels/')
# Out:
# Deleting directory 'MobileBERT_Classifier_Experimental/' from bucket 'arupreza-uids-models'...
# Directory 'MobileBERT_Classifier_Experimental/' deleted successfully.

# %%
def delete_entire_s3_bucket(bucket_name):

    # Deletes the bucket structure itself.
    try:
        print(f"Deleting bucket '{bucket_name}'...")

        bucket = s3_resource.Bucket(bucket_name)
        bucket.delete()

        print(f"Bucket '{bucket_name}' deleted successfully")

    except ClientError as e:
        print("AWS Error:", e.response['Error']['Message'])
    except Exception as e:
        print("Unexpected error:", e)

# %%
delete_entire_s3_bucket('arupreza-uids-models')
# Out:
# Deleting bucket 'arupreza-uids-models'...
# Bucket 'arupreza-uids-models' deleted successfully
